# %%
# %matplotlib inline
import re
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor
from sklearn import decomposition, preprocessing
from sklearn.decomposition import FactorAnalysis, PCA
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from IPython.display import display
import matplotlib.cm as cm

plt.rcParams['figure.figsize'] = (12.0, 10.0)

# %%
df = pd.read_csv('machines.csv')

# %%
df
# Out:
#                                             machine  \
# 0     \c220g1.quiho.schedock-pg0.wisc.cloudlab.us\"
# 1     \c220g2.quiho.schedock-pg0.wisc.cloudlab.us\"
# 2        \c6220.quiho.schedock-pg0.apt.emulab.net\"
# 3   \c6320.quiho.schedock-pg0.clemson.cloudlab.us\"
# 4   \c8220.quiho.schedock-pg0.clemson.cloudlab.us\"
# 5                \d2100.quiho.schedock.emulab.net\"
# 6                 \d430.quiho.schedock.emulab.net\"
# 7                 \d530.quiho.schedock.emulab.net\"
# 8                 \d710.quiho.schedock.emulab.net\"
# 9                 \d820.quiho.schedock.emulab.net\"
# 10  \dl360.quiho.emulab-net.utahddc.geniracks.net\"
# 11                                         \dwill\"
# 12                                      \issdm-41\"
# 13      \m510.quiho.schedock-pg0.utah.cloudlab.us\"
# 14        \pc2400.quiho.emulab-net.uky.emulab.net\"
# 15              \pc3000.quiho.schedock.emulab.net\"
# 16        \pc3300.quiho.emulab-net.uky.emulab.net\"
# ...

# %%
# remove unwanted characters
for c in ['machine', 'cpu', 'board_name']:
    df[c] = df[c].map(lambda x: x.lstrip('\\"').rstrip('\\"'))

# %%
len(df)
# Out:
# 22

# %%
with open("machines.tex", "w") as text_file:
    text_file.write(df.drop_duplicates(subset=['cpu','board_name'], keep="last")[['machine','cpu','num_cpus','cores']].to_latex(index=False))
