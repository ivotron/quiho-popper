# %%
# %matplotlib inline
import re
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor
from sklearn import decomposition, preprocessing
from sklearn.decomposition import FactorAnalysis, PCA
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from IPython.display import display
import matplotlib.cm as cm

plt.rcParams['figure.figsize'] = (12.0, 10.0)

# %%
df = pd.read_csv('all-mysql-regression.csv')

# %%
df.columns
# Out:
# Index(['benchmark', 'machine', 'repetition', 'test', 'result'], dtype='object')

# %%
df.benchmark.unique()
# Out:
# array(['stressng', 'mysqlslap-mariadb-10.3.2', 'mysqlslap-mariadb-5.5.58'], dtype=object)

# %%
df.test.unique()
# Out:
# array(['af-alg', 'atomic', 'bigheap', 'brk', 'bsearch', 'cache', 'cpu',
#        'crypt', 'full', 'heapsort', 'hsearch', 'icache', 'lockbus',
#        'longjmp', 'lsearch', 'malloc', 'matrix', 'memcpy', 'mincore',
#        'mmap', 'mremap', 'msync', 'nop', nan, 'numa', 'oom-pipe', 'opcode',
#        'qsort', 'remap', 'resources', 'rmap', 'shm', 'shm-sysv', 'stack',
#        'stackmmap', 'str', 'stream', 'tsearch', 'vecmath', 'vm', 'vm-rw',
#        'vm-splice', 'zero', 'innodb_key', 'innodb_load', 'innodb_mixed',
#        'innodb_scan', 'innodb_update', 'memory_key', 'memory_load',
#        'memory_mixed', 'memory_scan', 'memory_update'], dtype=object)

# %%
df
# Out:
#                      benchmark  \
# 0                     stressng
# 1                     stressng
# 2                     stressng
# 3                     stressng
# 4                     stressng
# 5                     stressng
# 6                     stressng
# 7                     stressng
# 8                     stressng
# 9                     stressng
# 10                    stressng
# 11                    stressng
# 12                    stressng
# 13                    stressng
# 14                    stressng
# 15                    stressng
# 16                    stressng
# 17                    stressng
# 18                    stressng
# 19                    stressng
# 20                    stressng
# 21                    stressng
# 22                    stressng
# 23                    stressng
# 24                    stressng
# 25                    stressng
# 26                    stressng
# 27                    stressng
# 28                    stressng
# 29                    stressng
# ...                        ...
# 2490  mysqlslap-mariadb-5.5.58
# 2491  mysqlslap-mariadb-5.5.58
# 2492  mysqlslap-mariadb-5.5.58
# 2493  mysqlslap-mariadb-5.5.58
# 2494  mysqlslap-mariadb-5.5.58
# 2495  mysqlslap-mariadb-5.5.58
# 2496  mysqlslap-mariadb-5.5.58
# 2497  mysqlslap-mariadb-5.5.58
# 2498  mysqlslap-mariadb-5.5.58
# 2499  mysqlslap-mariadb-5.5.58
# 2500  mysqlslap-mariadb-5.5.58
# 2501  mysqlslap-mariadb-5.5.58
# 2502  mysqlslap-mariadb-5.5.58
# 2503  mysqlslap-mariadb-5.5.58
# 2504  mysqlslap-mariadb-5.5.58
# 2505  mysqlslap-mariadb-5.5.58
# 2506  mysqlslap-mariadb-5.5.58
# 2507  mysqlslap-mariadb-5.5.58
# 2508  mysqlslap-mariadb-5.5.58
# 2509  mysqlslap-mariadb-5.5.58
# 2510  mysqlslap-mariadb-5.5.58
# 2511  mysqlslap-mariadb-5.5.58
# 2512  mysqlslap-mariadb-5.5.58
# 2513  mysqlslap-mariadb-5.5.58
# 2514  mysqlslap-mariadb-5.5.58
# 2515  mysqlslap-mariadb-5.5.58
# 2516  mysqlslap-mariadb-5.5.58
# 2517  mysqlslap-mariadb-5.5.58
# 2518  mysqlslap-mariadb-5.5.58
# 2519  mysqlslap-mariadb-5.5.58
#
#                                                 machine  repetition  \
# 0     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 1     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 2     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 3     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 4     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 5     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 6     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 7     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 8     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 9     c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 10    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 11    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 12    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 13    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 14    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 15    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 16    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 17    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 18    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 19    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 20    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 21    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 22    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 23    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 24    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 25    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 26    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 27    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 28    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# 29    c220g2.quiho-ivotron.schedock-PG0.wisc.cloudla...           1
# ...                                                 ...         ...
# 2490                               scruffy.soe.ucsc.edu           3
# 2491                               scruffy.soe.ucsc.edu           3
# 2492                               scruffy.soe.ucsc.edu           3
# 2493                               scruffy.soe.ucsc.edu           3
# 2494                               scruffy.soe.ucsc.edu           3
# 2495                               scruffy.soe.ucsc.edu           3
# 2496                               scruffy.soe.ucsc.edu           3
# 2497                               scruffy.soe.ucsc.edu           3
# 2498                               scruffy.soe.ucsc.edu           3
# 2499                               scruffy.soe.ucsc.edu           3
# 2500                               scruffy.soe.ucsc.edu           4
# 2501                               scruffy.soe.ucsc.edu           4
# 2502                               scruffy.soe.ucsc.edu           4
# 2503                               scruffy.soe.ucsc.edu           4
# 2504                               scruffy.soe.ucsc.edu           4
# 2505                               scruffy.soe.ucsc.edu           4
# 2506                               scruffy.soe.ucsc.edu           4
# 2507                               scruffy.soe.ucsc.edu           4
# 2508                               scruffy.soe.ucsc.edu           4
# 2509                               scruffy.soe.ucsc.edu           4
# 2510                               scruffy.soe.ucsc.edu           5
# 2511                               scruffy.soe.ucsc.edu           5
# 2512                               scruffy.soe.ucsc.edu           5
# 2513                               scruffy.soe.ucsc.edu           5
# 2514                               scruffy.soe.ucsc.edu           5
# 2515                               scruffy.soe.ucsc.edu           5
# 2516                               scruffy.soe.ucsc.edu           5
# 2517                               scruffy.soe.ucsc.edu           5
# 2518                               scruffy.soe.ucsc.edu           5
# 2519                               scruffy.soe.ucsc.edu           5
#
#                test        result
# 0            af-alg  7.575326e+03
# 1            atomic  7.167529e+05
# 2           bigheap  3.576982e+04
# 3               brk  6.617058e+05
# 4           bsearch  3.885322e+02
# 5             cache  2.999974e+00
# 6               cpu  2.720356e+02
# 7             crypt  1.666639e+02
# 8              full  3.013758e+05
# 9          heapsort  4.900002e+00
# 10          hsearch  3.358601e+03
# 11           icache  1.011239e+03
# 12          lockbus  2.118251e+06
# 13          longjmp  1.190516e+05
# 14          lsearch  9.600032e+00
# 15           malloc  2.510557e+06
# 16           matrix  5.269818e+03
# 17           memcpy  1.120135e+03
# 18          mincore  5.201626e+04
# 19             mmap  1.199083e+00
# 20           mremap  1.689646e+01
# 21            msync  5.928842e+01
# 22              nop  1.935933e+05
# 23              NaN  5.586755e+05
# 24             numa  9.969596e+01
# 25         oom-pipe  0.000000e+00
# 26           opcode  7.410961e+02
# 27            qsort  1.030002e+01
# 28            remap  4.156560e+02
# 29        resources  1.453860e+03
# ...             ...           ...
# 2490     innodb_key  1.100000e-01
# 2491    innodb_load  1.900000e+01
# 2492   innodb_mixed  2.000000e-02
# 2493    innodb_scan  1.286000e+01
# 2494  innodb_update  3.100000e-01
# 2495     memory_key  1.000000e-01
# 2496    memory_load  2.740000e+00
# 2497   memory_mixed  0.000000e+00
# 2498    memory_scan  8.940000e+00
# 2499  memory_update  8.000000e-02
# 2500     innodb_key  1.100000e-01
# 2501    innodb_load  1.912000e+01
# 2502   innodb_mixed  0.000000e+00
# 2503    innodb_scan  1.289000e+01
# 2504  innodb_update  3.300000e-01
# 2505     memory_key  1.100000e-01
# 2506    memory_load  2.660000e+00
# 2507   memory_mixed  3.000000e-02
# 2508    memory_scan  8.990000e+00
# 2509  memory_update  7.000000e-02
# 2510     innodb_key  1.000000e-01
# 2511    innodb_load  1.901000e+01
# 2512   innodb_mixed  3.300000e-01
# 2513    innodb_scan  1.275000e+01
# 2514  innodb_update  3.000000e-01
# 2515     memory_key  1.100000e-01
# 2516    memory_load  2.680000e+00
# 2517   memory_mixed  3.000000e-02
# 2518    memory_scan  8.890000e+00
# 2519  memory_update  9.000000e-02
#
# [2520 rows x 5 columns]

# %%
df['machine+repetition'] = df.apply(lambda x: x['machine'] + '-' + str(x['repetition']), axis=1)

# %%
df['test'] = df.apply(lambda x: (x['benchmark'] + '-' + x['test']) if (x['test'] == 'memory_load' or x['test'] == 'innodb_load') else x['test'], axis=1)

# %%
df.test.unique()
# Out:
# array(['af-alg', 'atomic', 'bigheap', 'brk', 'bsearch', 'cache', 'cpu',
#        'crypt', 'full', 'heapsort', 'hsearch', 'icache', 'lockbus',
#        'longjmp', 'lsearch', 'malloc', 'matrix', 'memcpy', 'mincore',
#        'mmap', 'mremap', 'msync', 'nop', 'numa', 'oom-pipe', 'opcode',
#        'qsort', 'remap', 'resources', 'rmap', 'shm', 'shm-sysv', 'stack',
#        'stackmmap', 'str', 'stream', 'tsearch', 'vecmath', 'vm', 'vm-rw',
#        'vm-splice', 'zero', 'innodb_key',
#        'mysqlslap-mariadb-10.3.2-innodb_load', 'innodb_mixed',
#        'innodb_scan', 'innodb_update', 'memory_key',
#        'mysqlslap-mariadb-10.3.2-memory_load', 'memory_mixed',
#        'memory_scan', 'memory_update',
#        'mysqlslap-mariadb-5.5.58-innodb_load',
#        'mysqlslap-mariadb-5.5.58-memory_load'], dtype=object)

# %%
len(df.index)
# Out:
# 2480

# %%
df.dropna(inplace=True)

# %%
len(df.index)
# Out:
# 2480

# %%
# pivot table to obtain features, where each microbenchmark is a feature
features = df.pivot_table(index=["machine+repetition","test"], values=['result'], fill_value=0, aggfunc=np.mean).unstack().reset_index()

# %%
# flatten the index
cols = features.columns.get_level_values(1).values
cols[0] = 'machine+repetition'
features.columns = cols
features.dropna(inplace=True)

# %%
# get features that we'll use
feature_columns = list(pd.Index(df.query('benchmark == "stressng"')['test'].unique()))

# %%
feature_columns
# Out:
# ['af-alg',
#  'atomic',
#  'bigheap',
#  'brk',
#  'bsearch',
#  'cache',
#  'cpu',
#  'crypt',
#  'full',
#  'heapsort',
#  'hsearch',
#  'icache',
#  'lockbus',
#  'longjmp',
#  'lsearch',
#  'malloc',
#  'matrix',
#  'memcpy',
#  'mincore',
#  'mmap',
#  'mremap',
#  'msync',
#  'nop',
#  'numa',
#  'oom-pipe',
#  'opcode',
#  'qsort',
#  'remap',
#  'resources',
#  'rmap',
#  'shm',
#  'shm-sysv',
#  'stack',
#  'stackmmap',
#  'str',
#  'stream',
#  'tsearch',
#  'vecmath',
#  'vm',
#  'vm-rw',
#  'vm-splice',
#  'zero']

# %%
len(feature_columns)
# Out:
# 42

# %%
# what we can learn
features.columns.difference(feature_columns + ['machine+repetition'])
# Out:
# Index(['innodb_key', 'innodb_mixed', 'innodb_scan', 'innodb_update',
#        'memory_key', 'memory_mixed', 'memory_scan', 'memory_update',
#        'mysqlslap-mariadb-10.3.2-innodb_load',
#        'mysqlslap-mariadb-10.3.2-memory_load',
#        'mysqlslap-mariadb-5.5.58-innodb_load',
#        'mysqlslap-mariadb-5.5.58-memory_load'],
#       dtype='object')

# %%
features[feature_columns]
# Out:
#           af-alg         atomic       bigheap            brk     bsearch  \
# 0    7575.325747  716752.908854  35769.815432  661705.830718  388.532239
# 1    8532.126576  735150.878557  34754.017145  658528.704536  383.022853
# 2    7939.085921  734968.888003  34485.882373  659243.543091  380.674687
# 3    8007.228863  729222.785473  34383.413807  663169.980511  377.725667
# 4    7646.289936  732250.209099  34496.652350  666278.279545  383.708297
# 5    7463.353184  451593.254992  28855.035798  513928.626579  251.379988
# 6    7468.440419  451923.356985  28034.441505  511050.442007  251.410694
# 7    7626.168869  451581.600939  28665.558102  512053.111017  251.429978
# 8    7676.716052  451779.926462  28927.927605  515123.334240  251.409975
# 9    7899.648083  451789.912967  28738.185497  514798.938095  251.355510
# 10   6949.690031  552395.825168  32928.826086  637944.373491  323.079102
# 11   6872.237689  553988.856742  33259.142039  609309.361849  320.893834
# 12   6885.309576  551296.070527  34363.781665  638948.587891  320.608625
# 13   6906.580165  557182.320329  34528.567564  637569.103405  320.981802
# 14   6975.270538  553726.381349  34138.450304  636152.256850  320.026141
# 15  12987.988393  652489.933440  43369.205300  696114.986767  373.361352
# 16  13291.192512  661120.481144  44775.291656  697686.176448  371.042614
# 17  13188.527957  659337.509104  39386.513059  712952.376760  371.884638
# 18  13240.363244  658802.145050  45056.962862  720316.893615  371.966310
# 19  12899.516063  657350.916487  41948.070233  731851.213296  373.555374
# 20   7629.703402  541919.537881  47907.292179  789381.710430  310.002106
# 21   7588.619272  543914.416315  48161.256797  792222.268941  306.917715
# 22   7885.696235  543652.220279  47948.116918  786809.391046  308.933327
# 23   7524.067266  546775.610675  48195.471201  789196.494085  309.236734
# 24   7623.147002  538750.427754  48082.235272  789036.513062  309.215897

    mask[np.triu_indices_from(mask)] = True
    sns.heatmap(corrmatrix, mask=mask,
                xticklabels=corrmatrix.columns.values,
                yticklabels=corrmatrix.columns.values)
    return corrmatrix

# %%
# plot correlation matrix for all stressors
corrmatrix = plot_corrmatrix(features[feature_columns])
plt.savefig('../../../paper/figures/corrmatrix.png', dpi=300, bbox_inches='tight')

# %%
["{} = {}".format(i, np.mean(np.abs(corrmatrix[i])) < .5) for i in corrmatrix.columns]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in absolute
#   """Entry point for launching an IPython kernel.
# ['af-alg = True',
#  'atomic = False',
#  'bigheap = False',
#  'brk = False',
#  'bsearch = False',
#  'cache = True',
#  'cpu = False',
#  'crypt = False',
#  'full = False',
#  'heapsort = False',
#  'hsearch = False',
#  'icache = False',
#  'lockbus = False',
#  'longjmp = False',
#  'lsearch = False',
#  'malloc = False',
#  'matrix = False',
#  'memcpy = False',
#  'mincore = False',
#  'mmap = False',
#  'mremap = False',
#  'msync = True',
#  'nop = False',
#  'numa = False',
#  'oom-pipe = False',
#  'opcode = True',
#  'qsort = False',
#  'remap = False',
#  'resources = True',
#  'rmap = True',
#  'shm = False',
#  'shm-sysv = True',
#  'stack = True',
#  'stackmmap = True',
#  'str = False',
#  'stream = True',
#  'tsearch = False',
#  'vecmath = False',
#  'vm = True',
#  'vm-rw = False',
#  'vm-splice = False',
#  'zero = False']

# %%
#memory_stressors = ['bigheap','brk','full','lockbus','malloc','mmap','mremap','msync','numa','resources','rmap','remap','shm','shm-sysv','stackmmap','stream','vm', 'vm-rw', 'vm-splice', 'zero']

#memory_stressors = ['mremap', 'msync', 'rmap', 'shm-sysv', 'stackmmap', 'stream']
#cpu_stressors = list(pd.Index(feature_columns).difference(memory_stressors))
#vm_stressors = []

cpu_stressors = ['af-alg', 'atomic', 'bsearch', 'context', 'cpu', 'cpu-online', 'crypt', 'fp-error', 'getrandom', 'heapsort', 'hsearch', 'longjmp', 'lsearch', 'matrix', 'mergesort', 'nop', 'numa', 'opcode', 'qsort', 'rdrand', 'str', 'stream', 'tsc', 'tsearch', 'vecmath', 'wcs', 'zlib']
memory_stressors = ['atomic', 'bsearch', 'context', 'full', 'heapsort', 'hsearch', 'lockbus', 'lsearch', 'malloc', 'matrix', 'membarrier', 'memcpy', 'memfd', 'mergesort', 'mincore', 'null', 'numa', 'oom-pipe', 'pipe', 'qsort', 'remap', 'resources', 'rmap', 'stack', 'stackmmap', 'str', 'stream', 'tlb-shootdown', 'tmpfs', 'tsearch', 'vm', 'vm-rw', 'wcs', 'zero', 'zlib']
vm_stressors = ['bigheap', 'brk', 'madvise', 'malloc', 'mlock', 'mmap', 'mmapfork', 'mmapmany', 'mremap', 'msync', 'shm', 'shm-sysv', 'stack', 'stackmmap', 'tmpfs', 'userfaultfd', 'vm', 'vm-rw', 'vm-splice']

# %%
memory_stressors
# Out:
# ['atomic',
#  'bsearch',
#  'context',
#  'full',
#  'heapsort',
#  'hsearch',
#  'lockbus',
#  'lsearch',
#  'malloc',
#  'matrix',
#  'membarrier',
#  'memcpy',
#  'memfd',
#  'mergesort',
#  'mincore',
#  'null',
#  'numa',
#  'oom-pipe',
#  'pipe',
#  'qsort',
#  'remap',
#  'resources',
#  'rmap',
#  'stack',
#  'stackmmap',
#  'str',
#  'stream',
#  'tlb-shootdown',
#  'tmpfs',
#  'tsearch',
#  'vm',
#  'vm-rw',
#  'wcs',
#  'zero',
#  'zlib']

# %%
cpu_stressors
# Out:
# ['af-alg',
#  'atomic',
#  'bsearch',
#  'context',
#  'cpu',
#  'cpu-online',
#  'crypt',
#  'fp-error',
#  'getrandom',
#  'heapsort',
#  'hsearch',
#  'longjmp',
#  'lsearch',
#  'matrix',
#  'mergesort',
#  'nop',
#  'numa',
#  'opcode',
#  'qsort',
#  'rdrand',
#  'str',
#  'stream',
#  'tsc',
#  'tsearch',
#  'vecmath',
#  'wcs',
#  'zlib']

# %%
# gradient boosting regression
# taken from http://scikit-learn.org/stable/auto_examples/ensemble/plot_gradient_boosting_regression.html
# extended to normalize data

rs = np.random.RandomState(1)
z_scaler = StandardScaler()

def plot_importance(data, feats, apps):
    for b in apps:
        # normalize data
        z_data = z_scaler.fit_transform(data[feats])
        
        # fit using random forest regressor
        params = {'n_estimators': 1000, 'max_depth': 4, 'min_samples_split': 2,
                  'learning_rate': 0.01, 'loss': 'ls'}
        regr = GradientBoostingRegressor(**params)
        regr.fit(z_data, data[b])

        # Plot feature importance
        feature_importance = regr.feature_importances_
        # make importances relative to max importance
        feature_importance = 100.0 * (feature_importance / feature_importance.max())
        sorted_idx = np.argsort(feature_importance)
        pos = np.arange(sorted_idx.shape[0]) + .5
        plt.barh(pos, feature_importance[sorted_idx], align='center')
        plt.yticks(pos, np.array(feats)[sorted_idx])
        plt.xlabel('Relative Importance')
        plt.title(b)
        plt.show()

        # print aggregate importance for each class
        importances = pd.DataFrame({'feature':feats,'importance':np.round(feature_importance,3)})
        print('CPU: {}'.format(importances.sort_values(by='importance', ascending=False).query('feature in @cpu_stressors')['importance'].values[0]))
        print('MEM: {}'.format(importances.sort_values(by='importance', ascending=False).query('feature in @memory_stressors')['importance'].values[0]))
        print('VM: {}'.format(importances.sort_values(by='importance', ascending=False).query('feature in @vm_stressors')['importance'].values[0]))
        print('')

# %%
# taken from https://stackoverflow.com/a/5967539/389188
# {
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split('(\d+)', text) ]
# }

# %%
plot_importance(features, feature_columns, ['mysqlslap-mariadb-10.3.2-innodb_load', 'mysqlslap-mariadb-5.5.58-innodb_load'])
# Out:
# CPU: 3.305
# MEM: 5.426
# VM: 100.0
# CPU: 8.921
# MEM: 86.334
# VM: 100.0

# %%
plot_importance(features, feature_columns, ['copy-1'] + ['copy-2'] + ['copy-4'] + ['copy-20'])
# Out:
# CPU: 42.162
# MEM: 100.0
# VM: 73.181
# CPU: 71.487
# MEM: 89.398
# VM: 100.0
# CPU: 66.762
# MEM: 90.41
# VM: 100.0
# CPU: 100.0
# MEM: 100.0
# VM: 78.66

# %%
plot_importance(features, feature_columns, ['triad-1'] + ['triad-20'])
# Out:
# CPU: 100.0
# MEM: 100.0
# VM: 40.431
# CPU: 75.44
# MEM: 100.0
# VM: 100.0

# %%
plot_importance(features, feature_columns, ['scale-1', 'scale-20'])
# Out:
# CPU: 65.147
# MEM: 100.0
# VM: 67.652
# CPU: 100.0
# MEM: 100.0
# VM: 96.416

# %%
plot_importance(features, feature_columns, ['add-1'] + ['add-20'])
# Out:
# CPU: 100.0
# MEM: 69.932
# VM: 34.956
# CPU: 78.583
# MEM: 100.0
# VM: 100.0

# %%
# taken from http://jotterbach.github.io/2016/03/24/Principal_Component_Analysis/
#            https://github.com/jotterbach/Data-Exploration-and-Numerical-Experimentation/blob/master/Data-Analytics/PCA_Pitfalls.ipynb
z_scaler = StandardScaler()
z_data = z_scaler.fit_transform(features[feature_columns])
pca_stressors_norm = PCA().fit(z_data)
plt.semilogy(pca_stressors_norm.explained_variance_, '--o')
plt.xlabel('principal component', fontsize = 20);
plt.ylabel('explained variance', fontsize = 20);
plt.ylim([.0001,100])
# Out:
# (0.0001, 100)

# %%
df.machine.unique()
# Out:
# array(['c220g1.quiho2.schedock-PG0.wisc.cloudlab.us',
#        'c220g2.quiho2.schedock-PG0.wisc.cloudlab.us',
#        'c6220.quiho2.schedock-PG0.apt.emulab.net',
#        'c6320.quiho2.schedock-PG0.clemson.cloudlab.us',
#        'c8220.quiho2.schedock-PG0.clemson.cloudlab.us',
#        'd2100.quiho2.Schedock.emulab.net',
#        'd430.quiho2.Schedock.emulab.net',
#        'd530.quiho2.Schedock.emulab.net',
#        'd710.quiho2.Schedock.emulab.net',
#        'd820.quiho2.Schedock.emulab.net',
#        'dl360.quiho2.emulab-net.utahddc.geniracks.net',
#        'dwill.soe.ucsc.edu', 'issdm-41',
#        'm510.quiho2.schedock-PG0.utah.cloudlab.us',
#        'pc3000.quiho2.Schedock.emulab.net',
#        'pc3300.quiho2.emulab-net.uky.emulab.net',
#        'pc3400.quiho2.emulab-net.uky.emulab.net',
#        'pc3500.quiho2.emulab-net.uky.emulab.net',
#        'r320.quiho2.schedock-PG0.apt.emulab.net',
#        'r720.quiho2.schedock-PG0.apt.emulab.net', 'scruffy.soe.ucsc.edu'], dtype=object)

# %%
df.machine.unique()
# Out:
# array(['c220g1.quiho2.schedock-PG0.wisc.cloudlab.us',
#        'c220g2.quiho2.schedock-PG0.wisc.cloudlab.us',
#        'c6220.quiho2.schedock-PG0.apt.emulab.net',
#        'c6320.quiho2.schedock-PG0.clemson.cloudlab.us',
#        'c8220.quiho2.schedock-PG0.clemson.cloudlab.us',
#        'd2100.quiho2.Schedock.emulab.net',
#        'd430.quiho2.Schedock.emulab.net',
#        'd530.quiho2.Schedock.emulab.net',
#        'd710.quiho2.Schedock.emulab.net',
#        'd820.quiho2.Schedock.emulab.net',
#        'dl360.quiho2.emulab-net.utahddc.geniracks.net',
#        'dwill.soe.ucsc.edu', 'issdm-41',
#        'm510.quiho2.schedock-PG0.utah.cloudlab.us',
#        'pc3000.quiho2.Schedock.emulab.net',
#        'pc3300.quiho2.emulab-net.uky.emulab.net',
#        'pc3400.quiho2.emulab-net.uky.emulab.net',
#        'pc3500.quiho2.emulab-net.uky.emulab.net',
#        'r320.quiho2.schedock-PG0.apt.emulab.net',
#        'r720.quiho2.schedock-PG0.apt.emulab.net', 'scruffy.soe.ucsc.edu'], dtype=object)

# %%
sns.boxplot(x='test', y='result', data=df.query('benchmark != "stressng"'))
_ = plt.xticks(rotation=90)

# %%
ops = ['copy', 'scale', 'add', 'triad']
for streamop in ops:
    sns.pointplot(x='test', color='C{}'.format(ops.index(streamop)), y='result', data=df[df['test'].str.startswith(streamop)].query('benchmark == "stream"'), order=['{}-1'.format(streamop)] + ['{}-{}'.format(streamop, i) for i in range(2,22,2)])
    plt.xticks(rotation=90)

# %%
plt.semilogy(pca_stressors_norm.explained_variance_ratio_, '--o');
plt.semilogy(pca_stressors_norm.explained_variance_ratio_.cumsum(), '--o');
plt.xlabel('principal component', fontsize = 20);
plt.ylim([.0001,100])
# Out:
# (0.0001, 100)

# %%
n_comp = len(feature_columns)
pca_inv_data = pca_stressors_norm.inverse_transform(np.eye(n_comp))
fig = plt.figure(figsize=(10, 6.5))
plt.plot(pca_inv_data.mean(axis=0), '--o', label = 'mean')
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o', label = 'variance')
plt.legend(loc='lower right')
plt.ylabel('feature contribution', fontsize=20);
plt.xlabel('feature index', fontsize=20);
plt.tick_params(axis='both', which='major');
plt.tick_params(axis='both', which='minor');
plt.xlim([0, len(feature_columns)])
plt.legend(loc='lower right', fontsize=18)

# %%
# show indices where mean of variance is greater than a threshold
mean_threshold=0.035
np.where(np.abs(pca_inv_data.mean(axis=0)) > mean_threshold)
# Out:
# (array([ 0,  2,  8, 13, 19, 23, 27, 30, 31]),)

# %%
# show which stressors they correspond to
most_relevant = list(np.array(feature_columns)[np.where(np.abs(pca_inv_data.mean(axis=0)) > mean_threshold)])
most_relevant
# Out:
# ['af-alg',
#  'bigheap',
#  'full',
#  'longjmp',
#  'mmap',
#  'numa',
#  'remap',
#  'shm',
#  'shm-sysv']

# %%
# let's plot feature importance again, this time using only the most relevant features from above
plot_importance(features, ['remap', 'cpu'], apps)
# Out:
# CPU: 193.079
# MEM: 0
# VM: 0
# CPU: 163.173
# MEM: 0
# VM: 0
# CPU: 146.453
# MEM: 0
# VM: 0
# CPU: 157.496
# MEM: 0
# VM: 0
# CPU: 146.852
# MEM: 0
# VM: 0
# CPU: 137.602
# MEM: 0
# VM: 0
# CPU: 141.448
# MEM: 0
# VM: 0
# CPU: 128.502
# MEM: 0
# VM: 0
# CPU: 123.676
# MEM: 0
# VM: 0
# CPU: 132.336
# MEM: 0
# VM: 0
# CPU: 128.984
# MEM: 0
# VM: 0
# CPU: 128.47899999999998
# MEM: 0
# VM: 0
# CPU: 131.822
# MEM: 0
# VM: 0
# CPU: 133.985
# MEM: 0
# VM: 0

# %%
df_mpi =
